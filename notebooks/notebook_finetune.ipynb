# %% [markdown]
# ## Introduction
#
#
# Zhenwei Shi, Zhitao Wei, Zhihe Zhao, Zaiyi Liu - *Foundation Model for Quantitative CT Imaging Analysis in Lung Cancer*
#
# The notebook below gives an example to users for quantitaive CT imaging analysis for lugn cancer patients using the FM-LCT foundation model.

# %% [markdown]
# ### Setup the environment for the project

# %%
# %pip install -r ../requirements.txt
# Out:
# Looking in indexes: https://mirrors.bfsu.edu.cn/pypi/web/simple
# Collecting absl-py==2.0.0 (from -r ../requirements.txt (line 1))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/01/e4/dc0a1dcc4e74e08d7abedab278c795eef54a224363bb18f5692f416d834f/absl_py-2.0.0-py3-none-any.whl (130 kB)
# Collecting antlr4-python3-runtime==4.9.3 (from -r ../requirements.txt (line 2))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/3e/38/7859ff46355f76f8d19459005ca000b6e7012f2f1ca597746cbcd1fbfe5e/antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anyio==4.2.0 (from -r ../requirements.txt (line 3))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/bf/cd/d6d9bb1dadf73e7af02d18225cbd2c93f8552e13130484f1c8dcfece292b/anyio-4.2.0-py3-none-any.whl (85 kB)
# Collecting anytree==2.12.1 (from -r ../requirements.txt (line 4))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/6a/fb/ff946843e6b55ae9fda84df3964d6c233cd2261dface789f5be02ab79bc5/anytree-2.12.1-py3-none-any.whl (44 kB)
# Collecting appdirs==1.4.4 (from -r ../requirements.txt (line 5))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting argon2-cffi==23.1.0 (from -r ../requirements.txt (line 6))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a4/6a/e8a041599e78b6b3752da48000b14c8d1e8a04ded09c88c714ba047f34f5/argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting argon2-cffi-bindings==21.2.0 (from -r ../requirements.txt (line 7))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/ec/f7/378254e6dd7ae6f31fe40c8649eea7d4832a42243acaf0f1fff9083b2bed/argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting arrow==1.3.0 (from -r ../requirements.txt (line 8))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f8/ed/e97229a566617f2ae958a6b13e7cc0f585470eac730a73e9e82c32a3cdd2/arrow-1.3.0-py3-none-any.whl (66 kB)
# Requirement already satisfied: asttokens==2.4.1 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 9)) (2.4.1)
# Collecting async-lru==2.0.4 (from -r ../requirements.txt (line 10))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/fa/9f/3c3503693386c4b0f245eaf5ca6198e3b28879ca0a40bde6b0e319793453/async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Collecting attrs==23.1.0 (from -r ../requirements.txt (line 11))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f0/eb/fcb708c7bf5056045e9e98f62b93bd7467eb718b0202e7698eb11d66416c/attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting Babel==2.14.0 (from -r ../requirements.txt (line 12))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/0d/35/4196b21041e29a42dc4f05866d0c94fa26c9da88ce12c38c2265e42c82fb/Babel-2.14.0-py3-none-any.whl (11.0 MB)
# Requirement already satisfied: backcall==0.2.0 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 13)) (0.2.0)
# Collecting beautifulsoup4==4.12.2 (from -r ../requirements.txt (line 14))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/57/f4/a69c20ee4f660081a7dedb1ac57f29be9378e04edfcb90c526b923d4bebc/beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting bleach==6.1.0 (from -r ../requirements.txt (line 15))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ea/63/da7237f805089ecc28a3f36bca6a21c31fcbc2eb380f3b8f1be3312abd14/bleach-6.1.0-py3-none-any.whl (162 kB)
# Collecting cachetools==5.3.2 (from -r ../requirements.txt (line 16))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting certifi==2023.11.17 (from -r ../requirements.txt (line 17))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/64/62/428ef076be88fa93716b576e4a01f919d25968913e817077a386fcbe4f42/certifi-2023.11.17-py3-none-any.whl (162 kB)
# Collecting cffi==1.16.0 (from -r ../requirements.txt (line 18))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/ea/ac/e9e77bc385729035143e54cc8c4785bd480eaca9df17565963556b0b7a93/cffi-1.16.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.4/443.4 kB 4.5 MB/s eta 0:00:00a 0:00:01
# Collecting charset-normalizer==3.3.2 (from -r ../requirements.txt (line 19))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/98/69/5d8751b4b670d623aa7a47bef061d69c279e9f922f6705147983aa76c3ce/charset_normalizer-3.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 11.7 MB/s eta 0:00:00
# Collecting click==8.1.7 (from -r ../requirements.txt (line 20))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97 kB)
# Collecting comm==0.2.0 (from -r ../requirements.txt (line 21))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7b/a6/5fd0242e974914b139451eea0a61ed9fd2e47157e33a67939043c50a94dd/comm-0.2.0-py3-none-any.whl (7.0 kB)
# Collecting contourpy==1.1.1 (from -r ../requirements.txt (line 22))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/2b/c0/24c34c41a180f875419b536125799c61e2330b997d77a5a818a3bc3e08cd/contourpy-1.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.9/301.9 kB 20.5 MB/s eta 0:00:00
# Collecting cycler==0.12.1 (from -r ../requirements.txt (line 23))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting debugpy==1.8.0 (from -r ../requirements.txt (line 24))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/f7/79/6053a14f60e879b8cb1a42dadbbef8822603eadde79944c61e955309b622/debugpy-1.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 28.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: decorator==5.1.1 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 25)) (5.1.1)
# Collecting defusedxml==0.7.1 (from -r ../requirements.txt (line 26))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting docker-pycreds==0.4.0 (from -r ../requirements.txt (line 27))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting docopt==0.6.2 (from -r ../requirements.txt (line 28))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting easydict==1.11 (from -r ../requirements.txt (line 29))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/0a/d2/deb3296d08097fedd622d423c0ec8b68b78c1704b3f1545326f6ce05c75c/easydict-1.11.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting exceptiongroup==1.2.0 (from -r ../requirements.txt (line 30))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b8/9a/5028fd52db10e600f1c4674441b968cf2ea4959085bfb5b99fb1250e5f68/exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: executing==2.0.1 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 31)) (2.0.1)
# Collecting fastjsonschema==2.19.0 (from -r ../requirements.txt (line 32))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/63/e9/d3dca06ea6b8e58e65716973bc7d9bee9bc39ce233595aa04d04e89a1089/fastjsonschema-2.19.0-py3-none-any.whl (23 kB)
# Collecting filelock==3.13.1 (from -r ../requirements.txt (line 33))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/81/54/84d42a0bee35edba99dee7b59a8d4970eccdd44b99fe728ed912106fc781/filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting fonttools==4.47.0 (from -r ../requirements.txt (line 34))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/55/a7/f08f063c6ff1b2d3abd68cc4a6872143fbc0f99a83cc44b96944ff11f817/fonttools-4.47.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.9 MB/s eta 0:00:00a 0:00:01
# Collecting fqdn==1.5.1 (from -r ../requirements.txt (line 35))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/cf/58/8acf1b3e91c58313ce5cb67df61001fc9dcd21be4fadb76c1a2d540e09ed/fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting fsspec==2023.12.2 (from -r ../requirements.txt (line 36))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/70/25/fab23259a52ece5670dcb8452e1af34b89e6135ecc17cd4b54b4b479eac6/fsspec-2023.12.2-py3-none-any.whl (168 kB)
# Collecting gitdb==4.0.11 (from -r ../requirements.txt (line 37))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting GitPython==3.1.40 (from -r ../requirements.txt (line 38))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl (190 kB)
# Collecting google-auth==2.25.2 (from -r ../requirements.txt (line 39))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f4/d2/9f6f3b9c0fd486617816cff42e856afea079d0bad99f0e60dc186c76b881/google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
# Collecting google-auth-oauthlib==1.0.0 (from -r ../requirements.txt (line 40))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/4a/07/8d9a8186e6768b55dfffeb57c719bc03770cf8a970a074616ae6f9e26a57/google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting grpcio==1.60.0 (from -r ../requirements.txt (line 41))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/1d/a6/1a6439ee3ade8faa0248f22d7dbcf244d9902568805b08f22776a2adaa22/grpcio-1.60.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 5.3 MB/s eta 0:00:0000:0100:010m
# Collecting huggingface-hub==0.20.1 (from -r ../requirements.txt (line 42))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a0/0a/02ac0ae1047d97769003ff4fb8e6717024f3f174a5d13257415aa09e13d9/huggingface_hub-0.20.1-py3-none-any.whl (330 kB)
# Collecting idna==3.6 (from -r ../requirements.txt (line 43))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c2/e7/a82b05cf63a603df6e68d59ae6a68bf5064484a0718ea5033660af4b54a9/idna-3.6-py3-none-any.whl (61 kB)
# Collecting importlib-metadata==7.0.1 (from -r ../requirements.txt (line 44))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c0/8b/d8427f023c081a8303e6ac7209c16e6878f2765d5b59667f3903fbcfd365/importlib_metadata-7.0.1-py3-none-any.whl (23 kB)
# Collecting importlib-resources==6.1.1 (from -r ../requirements.txt (line 45))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting ipykernel==6.27.1 (from -r ../requirements.txt (line 46))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/73/14/ec9a1c42d2c952c848a1ac366718783ab725148faf910bc086601809cefd/ipykernel-6.27.1-py3-none-any.whl (114 kB)
# Collecting ipython==8.12.3 (from -r ../requirements.txt (line 47))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/8d/97/8fe103906cd81bc42d3b0175b5534a9f67dccae47d6451131cf8d0d70bb2/ipython-8.12.3-py3-none-any.whl (798 kB)
# Collecting ipywidgets==8.1.1 (from -r ../requirements.txt (line 48))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/4a/0e/57ed498fafbc60419a9332d872e929879ceba2d73cb11d284d7112472b3e/ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Collecting isoduration==20.11.0 (from -r ../requirements.txt (line 49))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7b/55/e5326141505c5d5e34c5e0935d2908a74e4561eca44108fbfb9c13d2911a/isoduration-20.11.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: jedi==0.19.1 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 50)) (0.19.1)
# Collecting Jinja2==3.1.2 (from -r ../requirements.txt (line 51))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting joblib==1.3.2 (from -r ../requirements.txt (line 52))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting json5==0.9.14 (from -r ../requirements.txt (line 53))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/70/ba/fa37123a86ae8287d6678535a944f9c3377d8165e536310ed6f6cb0f0c0e/json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Collecting jsonpointer==2.4 (from -r ../requirements.txt (line 54))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/12/f6/0232cc0c617e195f06f810534d00b74d2f348fe71b2118009ad8ad31f878/jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting jsonschema==4.20.0 (from -r ../requirements.txt (line 55))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/0f/ed/0058234d8dd2b1fc6beeea8eab945191a05e9d391a63202f49fe23327586/jsonschema-4.20.0-py3-none-any.whl (84 kB)
# Collecting jsonschema-specifications==2023.12.1 (from -r ../requirements.txt (line 56))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ee/07/44bd408781594c4d0a027666ef27fab1e441b109dc3b76b4f836f8fd04fe/jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Collecting jupyter==1.0.0 (from -r ../requirements.txt (line 57))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/83/df/0f5dd132200728a86190397e1ea87cd76244e42d39ec5e88efd25b2abd7e/jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting jupyter-console==6.6.3 (from -r ../requirements.txt (line 58))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ca/77/71d78d58f15c22db16328a476426f7ac4a60d3a5a7ba3b9627ee2f7903d4/jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting jupyter-events==0.9.0 (from -r ../requirements.txt (line 59))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e3/55/0c1aa72f4317e826a471dc4adc3036acd11d496ded68c4bbac2a88551519/jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Collecting jupyter-lsp==2.2.1 (from -r ../requirements.txt (line 60))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a6/b9/bb98cc91cda084a2756938682d02bdaf221a38f30b7126ba65ed7cde3ea6/jupyter_lsp-2.2.1-py3-none-any.whl (66 kB)
# Collecting jupyter_client==8.6.0 (from -r ../requirements.txt (line 61))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/43/ae/5f4f72980765e2e5e02b260f9c53bcc706cefa7ac9c8d7240225c55788d4/jupyter_client-8.6.0-py3-none-any.whl (105 kB)
# Collecting jupyter_core==5.5.1 (from -r ../requirements.txt (line 62))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/af/51/762357eb0ab8d97751783354ac89cb1a4255dd94e955c5a8e379294c23a8/jupyter_core-5.5.1-py3-none-any.whl (28 kB)
# Collecting jupyter_server==2.12.1 (from -r ../requirements.txt (line 63))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ed/20/2437a3865083360103b0218e82a910c4c35f3bf7248c5cdae6934ba4d01c/jupyter_server-2.12.1-py3-none-any.whl (380 kB)
# Collecting jupyter_server_terminals==0.5.0 (from -r ../requirements.txt (line 64))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/63/9a/98d252b7977ac3aa0aa4152b87b356e2048d4b193f38840c0e00dd85fadc/jupyter_server_terminals-0.5.0-py3-none-any.whl (13 kB)
# Collecting jupyterlab==4.0.9 (from -r ../requirements.txt (line 65))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a7/f2/b3ed35a9d75c22c7a90dc51963e57373d000007ba3ccbfc6277ba6448aa8/jupyterlab-4.0.9-py3-none-any.whl (9.2 MB)
# Collecting jupyterlab-widgets==3.0.9 (from -r ../requirements.txt (line 66))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e8/05/0ebab152288693b5ec7b339aab857362947031143b282853b4c2dd4b5b40/jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Collecting jupyterlab_pygments==0.3.0 (from -r ../requirements.txt (line 67))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b1/dd/ead9d8ea85bf202d90cc513b533f9c363121c7792674f78e0d8a854b63b4/jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting jupyterlab_server==2.25.2 (from -r ../requirements.txt (line 68))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a2/97/abbbe35fc67b6f9423309988f2e411f7cb117b08321866d3d8b720f4c0d4/jupyterlab_server-2.25.2-py3-none-any.whl (58 kB)
# Collecting kiwisolver==1.4.5 (from -r ../requirements.txt (line 69))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/c0/a8/841594f11d0b88d8aeb26991bc4dac38baa909dc58d0c4262a4f7893bcbf/kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.5 MB/s eta 0:00:00a 0:00:01
# Collecting lightning-utilities==0.10.0 (from -r ../requirements.txt (line 70))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/5e/f4/07b748cb9834848de16aaeb1ae38bc9cfcfe3adc22ee2c8ebbe11db82795/lightning_utilities-0.10.0-py3-none-any.whl (24 kB)
# Collecting llvmlite==0.41.1 (from -r ../requirements.txt (line 71))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/be/a6/55020df7f04666bceb3ccc5dc0cb0812d68d5fdec883ff015a9110928829/llvmlite-0.41.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 MB 41.3 MB/s eta 0:00:0000:0100:01
# Collecting Markdown==3.5.1 (from -r ../requirements.txt (line 72))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/70/58/2c5a654173937d9f540a4971c569b44dcd55e5424a484d954cdaeebcf79c/Markdown-3.5.1-py3-none-any.whl (102 kB)
# Collecting MarkupSafe==2.1.3 (from -r ../requirements.txt (line 73))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/de/63/cb7e71984e9159ec5f45b5e81e896c8bdd0e45fe3fc6ce02ab497f0d790e/MarkupSafe-2.1.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting matplotlib==3.7.4 (from -r ../requirements.txt (line 74))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/a6/40/b96fead00529e68e0609971d9b8e99ba2d13cabb016ebf128aadde30d89b/matplotlib-3.7.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 67.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 75)) (0.1.6)
# Collecting mistune==3.0.2 (from -r ../requirements.txt (line 76))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f0/74/c95adcdf032956d9ef6c89a9b8a5152bf73915f8c633f3e3d88d06bd699c/mistune-3.0.2-py3-none-any.whl (47 kB)
# Collecting monai==1.3.0 (from -r ../requirements.txt (line 77))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/08/94/e8a7ba00dd0c7ce959648b562043bd22125d65f5e519e566c822f71bc437/monai-1.3.0-202310121228-py3-none-any.whl (1.3 MB)
# Collecting mpmath==1.3.0 (from -r ../requirements.txt (line 78))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting nbclient==0.9.0 (from -r ../requirements.txt (line 79))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/6b/3a/607149974149f847125c38a62b9ea2b8267eb74823bbf8d8c54ae0212a00/nbclient-0.9.0-py3-none-any.whl (24 kB)
# Collecting nbconvert==7.13.1 (from -r ../requirements.txt (line 80))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/be/80/aa90a9fea4893b6ffb584ce5c61f3497fb76febe5648f9bc257b15a29ded/nbconvert-7.13.1-py3-none-any.whl (256 kB)
# Collecting nbformat==5.9.2 (from -r ../requirements.txt (line 81))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f4/e7/ef30a90b70eba39e675689b9eaaa92530a71d7435ab8f9cae520814e0caf/nbformat-5.9.2-py3-none-any.whl (77 kB)
# Collecting nest-asyncio==1.5.8 (from -r ../requirements.txt (line 82))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ab/d3/48c01d1944e0ee49fdc005bf518a68b0582d3bd201e5401664890b62a647/nest_asyncio-1.5.8-py3-none-any.whl (5.3 kB)
# Collecting networkx==3.1 (from -r ../requirements.txt (line 83))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a8/05/9d4f9b78ead6b2661d6e8ea772e111fc4a9fbd866ad0c81906c11206b55e/networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting notebook==7.0.6 (from -r ../requirements.txt (line 84))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f3/2b/b904c57709b83c6cbd818d21040db36719207f3d17db9b124c60cd483d94/notebook-7.0.6-py3-none-any.whl (4.0 MB)
# Collecting notebook_shim==0.2.3 (from -r ../requirements.txt (line 85))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f4/79/73250372e5bbab63018b41b02d5cc6b395655ec6c1254e477ef7c913aada/notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting numba==0.58.1 (from -r ../requirements.txt (line 86))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/8b/4b/58bdecd06266c5395157727d7191d83c82d190665bdf3d65fdd67a6dbaa5/numba-0.58.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 75.1 MB/s eta 0:00:00a 0:00:01
# Collecting numpy==1.24.4 (from -r ../requirements.txt (line 87))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/7a/7c/d7b2a0417af6428440c0ad7cb9799073e507b1a465f827d058b826236964/numpy-1.24.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 51.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.1.3.1 (from -r ../requirements.txt (line 88))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/37/6d/121efd7382d5b0284239f4ab1fc1590d86d34ed4a4a2fdb13b30ca8e5740/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from -r ../requirements.txt (line 89))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7e/00/6b218edd739ecfc60524e585ba8e6b00554dd908de2c9c66c1af3e44e18d/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from -r ../requirements.txt (line 90))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b6/9f/c64c03f49d6fbc56196664d05dba14e3a561038a81a638eeb47f4d4cfd48/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from -r ../requirements.txt (line 91))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/eb/d5/c68b1d2cdfcc59e72e8a5949a37ddb22ae6cade80cd4a57a84d4c8b55472/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from -r ../requirements.txt (line 92))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ff/74/a2e2be7fb83aaedec84f391f082cf765dfb635e7caa9b49065f73e4835d8/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from -r ../requirements.txt (line 93))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/86/94/eb540db023ce1d162e7bea9f8f5aa781d57c65aed513c33ee9a5123ead4d/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from -r ../requirements.txt (line 94))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/44/31/4890b1c9abc496303412947fc7dcea3d14861720642b49e8ceed89636705/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from -r ../requirements.txt (line 95))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/bc/1d/8de1e5c67099015c834315e333911273a8c6aaba78923dd1d1e25fc5f217/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from -r ../requirements.txt (line 96))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/65/5b/cfaeebf25cd9fdec14338ccb16f6b2c4c7fa9163aefcf057d86b9cc248bb/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.18.1 (from -r ../requirements.txt (line 97))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a4/05/23f8f38eec3d28e4915725b233c24d8f1a33cb6540a882f7b54be1befa02/nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
# Collecting nvidia-nvjitlink-cu12==12.3.101 (from -r ../requirements.txt (line 98))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/1e/07/bf730d44c2fe1b676ad9cc2be5f5f861eb5d153fb6951987a2d6a96379a9/nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from -r ../requirements.txt (line 99))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/da/d3/8057f0587683ed2fcd4dbfbdfdfa807b9160b809976099d36b8f60d08f03/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting oauthlib==3.2.2 (from -r ../requirements.txt (line 100))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7e/80/cab10959dc1faead58dc8384a781dfbf93cb4d33d50988f7a69f1b7c9bbe/oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting omegaconf==2.3.0 (from -r ../requirements.txt (line 101))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e3/94/1843518e420fa3ed6919835845df698c7e27e183cb997394e4a670973a65/omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting overrides==7.4.0 (from -r ../requirements.txt (line 102))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/da/28/3fa6ef8297302fc7b3844980b6c5dbc71cdbd4b61e9b2591234214d5ab39/overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting opencv-python==4.8.1.78 (from -r ../requirements.txt (line 103))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b7/8a/b2f7e1a434d56bf1d7570fc5941ace0847404e1032d7f1f0b8fed896568d/opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# Requirement already satisfied: packaging==23.2 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 104)) (23.2)
# Collecting pandas==2.0.3 (from -r ../requirements.txt (line 105))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/9e/0d/91a9fd2c202f2b1d97a38ab591890f86480ecbb596cbc56d035f6f23fdcc/pandas-2.0.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 66.7 MB/s eta 0:00:0000:0100:01
# Collecting pandocfilters==1.5.0 (from -r ../requirements.txt (line 106))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/5e/a8/878258cffd53202a6cc1903c226cf09e58ae3df6b09f8ddfa98033286637/pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: parso==0.8.3 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 107)) (0.8.3)
# Requirement already satisfied: pexpect==4.9.0 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 108)) (4.9.0)
# Requirement already satisfied: pickleshare==0.7.5 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 109)) (0.7.5)
# Collecting Pillow==10.1.0 (from -r ../requirements.txt (line 110))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/5c/dc/acccca38a87272cb2eed372f112595439418dfb6119770b04dc06d3b78bd/Pillow-10.1.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 73.8 MB/s eta 0:00:00a 0:00:01
# Collecting pipreqs==0.4.13 (from -r ../requirements.txt (line 111))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d9/ea/74c89d786cf3403bfbf8fb70142fdf501af9517d0bb8c1acce3ee5ab613e/pipreqs-0.4.13-py2.py3-none-any.whl (33 kB)
# Collecting pkgutil_resolve_name==1.3.10 (from -r ../requirements.txt (line 112))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c9/5c/3d4882ba113fd55bdba9326c1e4c62a15e674a2501de4869e6bd6301f87e/pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Collecting platformdirs==4.1.0 (from -r ../requirements.txt (line 113))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/be/53/42fe5eab4a09d251a76d0043e018172db324a23fcdac70f77a551c11f618/platformdirs-4.1.0-py3-none-any.whl (17 kB)
# Collecting prometheus-client==0.19.0 (from -r ../requirements.txt (line 114))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/bb/9f/ad934418c48d01269fc2af02229ff64bcf793fd5d7f8f82dc5e7ea7ef149/prometheus_client-0.19.0-py3-none-any.whl (54 kB)
# Collecting prompt-toolkit==3.0.43 (from -r ../requirements.txt (line 115))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/ee/fd/ca7bf3869e7caa7a037e23078539467b433a4e01eebd93f77180ab927766/prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
# Collecting protobuf==3.20.0 (from -r ../requirements.txt (line 116))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/7f/d9/6b9e97c6498a29c5e99badce383a8711c4f0ff586a464851b3f8b06cc66d/protobuf-3.20.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.7 MB/s eta 0:00:00
# Collecting psutil==5.9.7 (from -r ../requirements.txt (line 117))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/be/fa/f1f626620e3b47e6237dcc64cb8cc1472f139e99422e5b9fa5bbcf457f48/psutil-5.9.7-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (285 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 118)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 119)) (0.2.2)
# Collecting pyasn1==0.5.1 (from -r ../requirements.txt (line 120))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d1/75/4686d2872bf2fc0b37917cbc8bbf0dd3a5cdb0990799be1b9cbf1e1eb733/pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Collecting pyasn1-modules==0.3.0 (from -r ../requirements.txt (line 121))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/cd/8e/bea464350e1b8c6ed0da3a312659cb648804a08af6cacc6435867f74f8bd/pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting pycparser==2.21 (from -r ../requirements.txt (line 122))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/62/d5/5f610ebe421e85889f2e55e33b7f9a6795bd982198517d912eb1c76e1a53/pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: Pygments==2.17.2 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 123)) (2.17.2)
# Collecting pynndescent==0.5.11 (from -r ../requirements.txt (line 124))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/4e/82/0b9851a2fd4da9b57d7931446f5ebab92a98f1f35d3dc0dae5f9ed50a462/pynndescent-0.5.11-py3-none-any.whl (55 kB)
# Collecting pyparsing==3.1.1 (from -r ../requirements.txt (line 125))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/39/92/8486ede85fcc088f1b3dba4ce92dd29d126fd96b0008ea213167940a2475/pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 126)) (2.8.2)
# Collecting python-json-logger==2.0.7 (from -r ../requirements.txt (line 127))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/35/a6/145655273568ee78a581e734cf35beb9e33a370b29c5d3c8fee3744de29f/python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting pytz==2023.3.post1 (from -r ../requirements.txt (line 128))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/32/4d/aaf7eff5deb402fd9a24a1449a8119f00d74ae9c2efa79f8ef9994261fc2/pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting PyYAML==6.0.1 (from -r ../requirements.txt (line 129))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/7d/39/472f2554a0f1e825bd7c5afc11c817cd7a2f3657460f7159f691fbb37c51/PyYAML-6.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (738 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.9/738.9 kB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: pyzmq==25.1.2 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 130)) (25.1.2)
# Collecting qtconsole==5.5.1 (from -r ../requirements.txt (line 131))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d5/21/0887c50fa5bca7bfde29f65999a6ac234617f2a007b6b387aa4dc0ca36a8/qtconsole-5.5.1-py3-none-any.whl (123 kB)
# Collecting QtPy==2.4.1 (from -r ../requirements.txt (line 132))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7e/a9/2146d5117ad8a81185331e0809a6b48933c10171f5bac253c6df9fce991c/QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting referencing==0.32.0 (from -r ../requirements.txt (line 133))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/b4/11/d121780c173336c9bc3a5b8240ed31f518957cc22f6311c76259cb0fcf32/referencing-0.32.0-py3-none-any.whl (26 kB)
# Collecting requests==2.31.0 (from -r ../requirements.txt (line 134))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting requests-oauthlib==1.3.1 (from -r ../requirements.txt (line 135))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/6f/bb/5deac77a9af870143c684ab46a7934038a53eb4aa975bc0687ed6ca2c610/requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting rfc3339-validator==0.1.4 (from -r ../requirements.txt (line 136))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/7b/44/4e421b96b67b2daff264473f7465db72fbdf36a07e05494f50300cc7b0c6/rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator==0.1.1 (from -r ../requirements.txt (line 137))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/9e/51/17023c0f8f1869d8806b979a2bffa3f861f26a3f1a66b094288323fba52f/rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rpds-py==0.15.2 (from -r ../requirements.txt (line 138))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/13/de/2cf650e81270f3da659bfb38fd75d895c56588363afc459f8490e11caed7/rpds_py-0.15.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.6 MB/s eta 0:00:0000:0100:01
# Collecting rsa==4.9 (from -r ../requirements.txt (line 139))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/49/97/fa78e3d2f65c02c8e1268b9aba606569fe97f6c8f7c2d74394553347c145/rsa-4.9-py3-none-any.whl (34 kB)
# Collecting safetensors==0.4.1 (from -r ../requirements.txt (line 140))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/fb/5f/deffd66027e4652521d4cd4dd390a1482b4342f5aa99d86d466122300d6b/safetensors-0.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.8 MB/s eta 0:00:00
# Collecting scikit-learn==1.3.2 (from -r ../requirements.txt (line 141))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/25/89/dce01a35d354159dcc901e3c7e7eb3fe98de5cb3639c6cd39518d8830caa/scikit_learn-1.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 23.0 MB/s eta 0:00:00 0:00:01
# Collecting scikit-image==0.21.0 (from -r ../requirements.txt (line 142))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/19/bd/a53569a0a698d925eb46dbea0bd3b6b62e7287a9ec88b5a03efa8ebd5b14/scikit_image-0.21.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.7 MB/s eta 0:00:0000:0100:01
# Collecting scipy==1.10.1 (from -r ../requirements.txt (line 143))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/5d/30/b2a2a5bf1a3beefb7609fb871dcc6aef7217c69cef19a4631b7ab5622a8a/scipy-1.10.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 57.4 MB/s eta 0:00:0000:0100:01
# Collecting Send2Trash==1.8.2 (from -r ../requirements.txt (line 144))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a9/78/e4df1e080ed790acf3a704edf521006dd96b9841bd2e2a462c0d255e0565/Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting sentry-sdk==1.39.1 (from -r ../requirements.txt (line 145))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/aa/39/a40c841782b775eec1602a82387b4e91322ccafd842fd60fc4deb9f13f7d/sentry_sdk-1.39.1-py2.py3-none-any.whl (254 kB)
# Collecting setproctitle==1.3.3 (from -r ../requirements.txt (line 146))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/c3/9c/0ff2dc4967c30fe1e60ef5d651547065e431380f8b30af0e8fafadcb2a26/setproctitle-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting SimpleITK==2.3.1 (from -r ../requirements.txt (line 147))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/bf/d3/9e8d483f3e7104568e29a886d76d9fa1d6b6dabbb7bdb0ca1d878f332fc9/SimpleITK-2.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 39.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six==1.16.0 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 148)) (1.16.0)
# Collecting smmap==5.0.1 (from -r ../requirements.txt (line 149))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl (24 kB)
# Collecting sniffio==1.3.0 (from -r ../requirements.txt (line 150))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c3/a0/5dba8ed157b0136607c7f2151db695885606968d1fae123dc3391e0cfdbf/sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting soupsieve==2.5 (from -r ../requirements.txt (line 151))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting stack-data==0.6.3 (from -r ../requirements.txt (line 152))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f1/7b/ce1eafaf1a76852e2ec9b22edecf1daa58175c090266e9f6c64afcd81d91/stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting sympy==1.12 (from -r ../requirements.txt (line 153))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d2/05/e6600db80270777c4a64238a98d442f0fd07cc8915be2a1c16da7f2b9e74/sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting tensorboard==2.14.0 (from -r ../requirements.txt (line 154))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/bc/a2/ff5f4c299eb37c95299a76015da3f30211468e29d8d6f1d011683279baee/tensorboard-2.14.0-py3-none-any.whl (5.5 MB)
# Collecting tensorboard-data-server==0.7.2 (from -r ../requirements.txt (line 155))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/73/c6/825dab04195756cf8ff2e12698f22513b3db2f64925bdd41671bfb33aaa5/tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Collecting ttach==0.0.3 (from -r ../requirements.txt (line 156))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/8d/a3/ee48a184a185c1897c582c72240c2c8a0d0aeb5f8051a71d4e4cd930c52d/ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Collecting tfrecord==1.14.4 (from -r ../requirements.txt (line 157))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/2f/ad/d72181e3b2ac28574d3fd4d690e073068a720c1090316b1705d171fd4ecd/tfrecord-1.14.4-py3-none-any.whl (15 kB)
# Collecting terminado==0.18.0 (from -r ../requirements.txt (line 158))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/69/df/deebc9fb14a49062a3330f673e80b100e665b54d998163b3f62620b6240c/terminado-0.18.0-py3-none-any.whl (14 kB)
# Collecting threadpoolctl==3.2.0 (from -r ../requirements.txt (line 159))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting timm==0.9.10 (from -r ../requirements.txt (line 160))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/f0/1e/05287cb8984229d101874433df472b1fa3dcd6f746ccb6e8a26c7deeb1c7/timm-0.9.10-py3-none-any.whl (2.2 MB)
# Collecting tinycss2==1.2.1 (from -r ../requirements.txt (line 161))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/da/99/fd23634d6962c2791fb8cb6ccae1f05dcbfc39bce36bba8b1c9a8d92eae8/tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting tomli==2.0.1 (from -r ../requirements.txt (line 162))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/97/75/10a9ebee3fd790d20926a90a2547f0bf78f371b2f13aa822c759680ca7b9/tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting torch==2.1.2 (from -r ../requirements.txt (line 163))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/da/57/0a58fb9a7d110eab4492fe984bc207d51706797d0729dbd8ce7ff982c82e/torch-2.1.2-cp39-cp39-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting torchmetrics==1.2.1 (from -r ../requirements.txt (line 164))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/62/17/eedb48177a4679b75b82185492f8ad2b4d010e032fd38160e157b0e22028/torchmetrics-1.2.1-py3-none-any.whl (806 kB)
# Collecting torchprofile==0.0.4 (from -r ../requirements.txt (line 165))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/62/15/71ad4ed163b03cba1315f1d96e0bc8e39d5a97f92974ffa610a729b273ab/torchprofile-0.0.4-py3-none-any.whl (7.7 kB)
# Collecting torchvision==0.16.2 (from -r ../requirements.txt (line 166))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/a3/19/2f586c109711337ba5c5b713c03d56b42a74aee966ac0bba64458dea84a1/torchvision-0.16.2-cp39-cp39-manylinux1_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 41.6 MB/s eta 0:00:0000:0100:01
# Collecting tornado==6.4 (from -r ../requirements.txt (line 167))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/9f/12/11d0a757bb67278d3380d41955ae98527d5ad18330b2edbdc8de222b569b/tornado-6.4-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
# Collecting tqdm==4.66.1 (from -r ../requirements.txt (line 168))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl (78 kB)
# Collecting traitlets==5.14.0 (from -r ../requirements.txt (line 169))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a7/1d/7d07e1b152b419a8a9c7f812eeefd408a0610d869489ee2e86973486713f/traitlets-5.14.0-py3-none-any.whl (85 kB)
# Collecting triton==2.1.0 (from -r ../requirements.txt (line 170))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/d1/5a/e5811fcc8fc6703be39eb157af6224eaa3b628a42008df93b87e23eb9731/triton-2.1.0-0-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 MB 36.0 MB/s eta 0:00:0000:0100:01
# Collecting types-python-dateutil==2.8.19.14 (from -r ../requirements.txt (line 171))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/1c/af/5af2e2a02bc464c1c7818c260606343020b96c0d5b64f637d9e91aee24fe/types_python_dateutil-2.8.19.14-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: typing_extensions==4.9.0 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from -r ../requirements.txt (line 172)) (4.9.0)
# Collecting tzdata==2023.3 (from -r ../requirements.txt (line 173))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d5/fb/a79efcab32b8a1f1ddca7f35109a50e4a80d42ac1c9187ab46522b2407d7/tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting umap-learn==0.5.5 (from -r ../requirements.txt (line 174))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/4f/3c/a81281db93878bcd80da672a9b520674f930e0a18d73a2e4b23e8b176cb6/umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting uri-template==1.3.0 (from -r ../requirements.txt (line 175))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/e7/00/3fca040d7cf8a32776d3d81a00c8ee7457e00f80c649f1e4a863c8321ae9/uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting urllib3==2.1.0 (from -r ../requirements.txt (line 176))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/96/94/c31f58c7a7f470d5665935262ebd7455c7e4c7782eb525658d3dbf4b9403/urllib3-2.1.0-py3-none-any.whl (104 kB)
# Collecting wandb==0.16.1 (from -r ../requirements.txt (line 177))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/35/d3/6bfe29e4ba1eb2400d478caf8e3af9a1c366390390069cda59a7c6bf6063/wandb-0.16.1-py3-none-any.whl (2.1 MB)
# Collecting wcwidth==0.2.12 (from -r ../requirements.txt (line 178))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Collecting webcolors==1.13 (from -r ../requirements.txt (line 179))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d5/e1/3e9013159b4cbb71df9bd7611cbf90dc2c621c8aeeb677fc41dad72f2261/webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting webencodings==0.5.1 (from -r ../requirements.txt (line 180))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/f4/24/2a3e3df732393fed8b3ebf2ec078f05546de641fe1b667ee316ec1dcf3b7/webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting websocket-client==1.7.0 (from -r ../requirements.txt (line 181))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/1e/70/1e88138a9afbed1d37093b85f0bebc3011623c4f47c166431599fe9d6c93/websocket_client-1.7.0-py3-none-any.whl (58 kB)
# Collecting Werkzeug==3.0.1 (from -r ../requirements.txt (line 182))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c3/fc/254c3e9b5feb89ff5b9076a23218dafbc99c96ac5941e900b71206e6313b/werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Collecting widgetsnbextension==4.0.9 (from -r ../requirements.txt (line 183))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/29/03/107d96077c4befed191f7ad1a12c7b52a8f9d2778a5836d59f9855c105f6/widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Collecting yarg==0.1.9 (from -r ../requirements.txt (line 184))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/8b/90/89a2ff242ccab6a24fbab18dbbabc67c51a6f0ed01f9a0f41689dc177419/yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting zipp==3.17.0 (from -r ../requirements.txt (line 185))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting seaborn==0.13.1 (from -r ../requirements.txt (line 186))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/2d/46/cf3fce41ffc543b6e94dadbe6b647559d591df446ec716e72c3b4ce71b34/seaborn-0.13.1-py3-none-any.whl (294 kB)
# Collecting shap==0.44.0 (from -r ../requirements.txt (line 187))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/44/31/1ea23b817be0a994675d8786be4c1db1a9e387efb6bfd7126bf7a48b9c2b/shap-0.44.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.4/533.4 kB 9.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from lightning-utilities==0.10.0->-r ../requirements.txt (line 70)) (68.2.2)
# Collecting imageio>=2.27 (from scikit-image==0.21.0->-r ../requirements.txt (line 142))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/c0/69/3aaa69cb0748e33e644fda114c9abd3186ce369edd4fca11107e9f39c6a7/imageio-2.33.1-py3-none-any.whl (313 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image==0.21.0->-r ../requirements.txt (line 142))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/16/09/b9f5e4f9448fd39b7c0c9cbb592409ab28e90a1913795260b975d8424cde/tifffile-2024.1.30-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.1/224.1 kB 30.2 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.21.0->-r ../requirements.txt (line 142))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/a7/58/1724d6362becfa71eded2dffe145e795786b13c3a66f6523f3aff1b3f3cf/pywavelets-1.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 64.7 MB/s eta 0:00:0000:0100:01
# Collecting lazy_loader>=0.2 (from scikit-image==0.21.0->-r ../requirements.txt (line 142))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/a1/c3/65b3814e155836acacf720e5be3b5757130346670ac454fee29d3eda1381/lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: wheel>=0.26 in /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages (from tensorboard==2.14.0->-r ../requirements.txt (line 154)) (0.41.2)
# Collecting crc32c (from tfrecord==1.14.4->-r ../requirements.txt (line 157))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/56/70/9bc4e4b676472af3c052d81a3e8b83fe72bf75f37d4d3a1fa226588521a7/crc32c-2.3.post0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 8.0 MB/s eta 0:00:00
# Collecting slicer==0.0.7 (from shap==0.44.0->-r ../requirements.txt (line 187))
#   Using cached https://mirrors.bfsu.edu.cn/pypi/web/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting cloudpickle (from shap==0.44.0->-r ../requirements.txt (line 187))
#   Downloading https://mirrors.bfsu.edu.cn/pypi/web/packages/96/43/dae06432d0c4b1dc9e9149ad37b4ca8384cf6eb7700cd9215b177b914f0a/cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Building wheels for collected packages: antlr4-python3-runtime, docopt, easydict, umap-learn
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=b07e8dd76aee47e9816dc8b1314e926c097e0f1117469238cc19bc96da53178c
#   Stored in directory: /home/zhenwei/.cache/pip/wheels/b3/3a/29/49fd64ef11d8c1ceac019929299934513a7d5cdf68991ad6eb
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=6f6ae74c73315ee85f7a4009ebe314acc74bda3b797ea7a317d53c0fc983ec86
#   Stored in directory: /home/zhenwei/.cache/pip/wheels/15/10/88/30fe9f275cfe64fc24b73cccd6143afd83a1f85aa6160cc62c
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.11-py3-none-any.whl size=6660 sha256=60285bdd2117e52bbd6f06c9a47f99cda5277e8088cf7d16e34d862fe0c8cd41
#   Stored in directory: /home/zhenwei/.cache/pip/wheels/ee/1d/4e/5741bf3eaa33dd8d7808a3062b7b9ece16ea18cad3465e2147
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=c9fa500fcc35f3ea4c38409ef4a9d53a8d1e40083a4ff9ef509d6ca2c3ad6d08
#   Stored in directory: /home/zhenwei/.cache/pip/wheels/c3/ff/80/353f77f43e85f5e17b123b06eb6676e850fb4a72bc7bf70af4
# Successfully built antlr4-python3-runtime docopt easydict umap-learn
# Installing collected packages: webencodings, wcwidth, types-python-dateutil, SimpleITK, pytz, mpmath, json5, fastjsonschema, easydict, docopt, crc32c, appdirs, antlr4-python3-runtime, zipp, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, ttach, traitlets, tqdm, tornado, tomli, tinycss2, threadpoolctl, tensorboard-data-server, sympy, soupsieve, sniffio, smmap, slicer, setproctitle, Send2Trash, safetensors, rpds-py, rfc3986-validator, rfc3339-validator, QtPy, PyYAML, python-json-logger, pyparsing, pycparser, pyasn1, psutil, protobuf, prompt-toolkit, prometheus-client, platformdirs, pkgutil_resolve_name, Pillow, pandocfilters, overrides, oauthlib, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, nest-asyncio, mistune, MarkupSafe, llvmlite, lightning-utilities, lazy_loader, kiwisolver, jupyterlab-widgets, jupyterlab_pygments, jsonpointer, joblib, idna, grpcio, fsspec, fqdn, fonttools, filelock, exceptiongroup, docker-pycreds, defusedxml, debugpy, cycler, cloudpickle, click, charset-normalizer, certifi, cachetools, bleach, Babel, attrs, async-lru, anytree, absl-py, Werkzeug, triton, tifffile, tfrecord, terminado, stack-data, sentry-sdk, scipy, rsa, requests, referencing, PyWavelets, pyasn1-modules, pandas, opencv-python, omegaconf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, jupyter_core, Jinja2, importlib-resources, importlib-metadata, imageio, gitdb, contourpy, comm, cffi, beautifulsoup4, arrow, anyio, yarg, scikit-learn, scikit-image, requests-oauthlib, nvidia-cusolver-cu12, matplotlib, Markdown, jupyter_server_terminals, jupyter_client, jsonschema-specifications, isoduration, ipython, huggingface-hub, google-auth, GitPython, argon2-cffi-bindings, wandb, torch, shap, seaborn, pynndescent, pipreqs, jsonschema, ipywidgets, ipykernel, google-auth-oauthlib, argon2-cffi, umap-learn, torchvision, torchmetrics, tensorboard, qtconsole, nbformat, monai, jupyter-console, torchprofile, timm, nbclient, jupyter-events, nbconvert, jupyter_server, notebook_shim, jupyterlab_server, jupyter-lsp, jupyterlab, notebook, jupyter
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.14.1
#     Uninstalling traitlets-5.14.1:
#       Successfully uninstalled traitlets-5.14.1
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.42
#     Uninstalling prompt-toolkit-3.0.42:
#       Successfully uninstalled prompt-toolkit-3.0.42
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.2.0
#     Uninstalling platformdirs-4.2.0:
#       Successfully uninstalled platformdirs-4.2.0
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest_asyncio 1.6.0
#     Uninstalling nest_asyncio-1.6.0:
#       Successfully uninstalled nest_asyncio-1.6.0
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.6.7
#     Uninstalling debugpy-1.6.7:
#       Successfully uninstalled debugpy-1.6.7
#   Attempting uninstall: stack-data
#     Found existing installation: stack-data 0.6.2
#     Uninstalling stack-data-0.6.2:
#       Successfully uninstalled stack-data-0.6.2
#   Attempting uninstall: jupyter_core
#     Found existing installation: jupyter_core 5.7.1
#     Uninstalling jupyter_core-5.7.1:
#       Successfully uninstalled jupyter_core-5.7.1
#   Attempting uninstall: comm
#     Found existing installation: comm 0.2.1
#     Uninstalling comm-0.2.1:
#       Successfully uninstalled comm-0.2.1
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter-client 7.3.4
#     Uninstalling jupyter-client-7.3.4:
#       Successfully uninstalled jupyter-client-7.3.4
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.12.0
#     Uninstalling ipython-8.12.0:
#       Successfully uninstalled ipython-8.12.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.29.2
#     Uninstalling ipykernel-6.29.2:
#       Successfully uninstalled ipykernel-6.29.2
# Successfully installed Babel-2.14.0 GitPython-3.1.40 Jinja2-3.1.2 Markdown-3.5.1 MarkupSafe-2.1.3 Pillow-10.1.0 PyWavelets-1.5.0 PyYAML-6.0.1 QtPy-2.4.1 Send2Trash-1.8.2 SimpleITK-2.3.1 Werkzeug-3.0.1 absl-py-2.0.0 antlr4-python3-runtime-4.9.3 anyio-4.2.0 anytree-2.12.1 appdirs-1.4.4 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-23.1.0 beautifulsoup4-4.12.2 bleach-6.1.0 cachetools-5.3.2 certifi-2023.11.17 cffi-1.16.0 charset-normalizer-3.3.2 click-8.1.7 cloudpickle-3.0.0 comm-0.2.0 contourpy-1.1.1 crc32c-2.3.post0 cycler-0.12.1 debugpy-1.8.0 defusedxml-0.7.1 docker-pycreds-0.4.0 docopt-0.6.2 easydict-1.11 exceptiongroup-1.2.0 fastjsonschema-2.19.0 filelock-3.13.1 fonttools-4.47.0 fqdn-1.5.1 fsspec-2023.12.2 gitdb-4.0.11 google-auth-2.25.2 google-auth-oauthlib-1.0.0 grpcio-1.60.0 huggingface-hub-0.20.1 idna-3.6 imageio-2.33.1 importlib-metadata-7.0.1 importlib-resources-6.1.1 ipykernel-6.27.1 ipython-8.12.3 ipywidgets-8.1.1 isoduration-20.11.0 joblib-1.3.2 json5-0.9.14 jsonpointer-2.4 jsonschema-4.20.0 jsonschema-specifications-2023.12.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.9.0 jupyter-lsp-2.2.1 jupyter_client-8.6.0 jupyter_core-5.5.1 jupyter_server-2.12.1 jupyter_server_terminals-0.5.0 jupyterlab-4.0.9 jupyterlab-widgets-3.0.9 jupyterlab_pygments-0.3.0 jupyterlab_server-2.25.2 kiwisolver-1.4.5 lazy_loader-0.3 lightning-utilities-0.10.0 llvmlite-0.41.1 matplotlib-3.7.4 mistune-3.0.2 monai-1.3.0 mpmath-1.3.0 nbclient-0.9.0 nbconvert-7.13.1 nbformat-5.9.2 nest-asyncio-1.5.8 networkx-3.1 notebook-7.0.6 notebook_shim-0.2.3 numba-0.58.1 numpy-1.24.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 oauthlib-3.2.2 omegaconf-2.3.0 opencv-python-4.8.1.78 overrides-7.4.0 pandas-2.0.3 pandocfilters-1.5.0 pipreqs-0.4.13 pkgutil_resolve_name-1.3.10 platformdirs-4.1.0 prometheus-client-0.19.0 prompt-toolkit-3.0.43 protobuf-3.20.0 psutil-5.9.7 pyasn1-0.5.1 pyasn1-modules-0.3.0 pycparser-2.21 pynndescent-0.5.11 pyparsing-3.1.1 python-json-logger-2.0.7 pytz-2023.3.post1 qtconsole-5.5.1 referencing-0.32.0 requests-2.31.0 requests-oauthlib-1.3.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.15.2 rsa-4.9 safetensors-0.4.1 scikit-image-0.21.0 scikit-learn-1.3.2 scipy-1.10.1 seaborn-0.13.1 sentry-sdk-1.39.1 setproctitle-1.3.3 shap-0.44.0 slicer-0.0.7 smmap-5.0.1 sniffio-1.3.0 soupsieve-2.5 stack-data-0.6.3 sympy-1.12 tensorboard-2.14.0 tensorboard-data-server-0.7.2 terminado-0.18.0 tfrecord-1.14.4 threadpoolctl-3.2.0 tifffile-2024.1.30 timm-0.9.10 tinycss2-1.2.1 tomli-2.0.1 torch-2.1.2 torchmetrics-1.2.1 torchprofile-0.0.4 torchvision-0.16.2 tornado-6.4 tqdm-4.66.1 traitlets-5.14.0 triton-2.1.0 ttach-0.0.3 types-python-dateutil-2.8.19.14 tzdata-2023.3 umap-learn-0.5.5 uri-template-1.3.0 urllib3-2.1.0 wandb-0.16.1 wcwidth-0.2.12 webcolors-1.13 webencodings-0.5.1 websocket-client-1.7.0 widgetsnbextension-4.0.9 yarg-0.1.9 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../")

# %% [markdown]
# ### Load fmlct package and check data

# %%
import fmlct
from fmlct.lib.utils import pytree

pytree.tree("dataset/DATASET1", max_level=3)
# Out:
# DATASET1
# ├── Image
# │   ├── 1000287900_enhanced.nii.gz
# │   ├── 1000301641_enhanced.nii.gz
# │   ├── ...
# │   └── 1000340984_enhanced.nii.gz
# ├── Mask
# │   ├── 1000287900_enhanced.nii.gz
# │   ├── 1000301641_enhanced.nii.gz
# │   ├── ...
# │   └── 1000340984_enhanced.nii.gz
# └── label.csv

# %% [markdown]
# ### Image data and ROI preview

# %%
from fmlct.lib.utils import read_array, overlay_mask
from matplotlib import pyplot as plt

# Selecting a slice from the dataset
demo_image = read_array("dataset/DATASET1/Image/1000287900_enhanced.nii.gz")[200]
demo_mask = read_array("dataset/DATASET1/Mask/1000287900_enhanced.nii.gz")[200]

# Plotting the images
fig, axes = plt.subplots(1, 3, figsize=(10, 5))

# Original image
axes[0].imshow(demo_image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Combined image and mask
axes[1].imshow(overlay_mask(demo_image, demo_mask, alpha=0.5))
axes[1].set_title('Image with Mask Overlay')
axes[1].axis('off')

# Mask
axes[2].imshow(demo_mask, cmap='gray')
axes[2].set_title('Mask')
axes[2].axis('off')

plt.show()

# %%
# check data table
import pandas as pd

pd.read_csv("dataset/DATASET1/label.csv").head()
# Out:
#                          Name            PatientID  demo_label
# 0  1000287900_enhanced.nii.gz  1000287900_enhanced           1
# 1  1000301641_enhanced.nii.gz  1000301641_enhanced           0
# 2  1000340984_enhanced.nii.gz  1000340984_enhanced           0
# 3  1000356625_enhanced.nii.gz  1000356625_enhanced           0
# 4  1000403459_enhanced.nii.gz  1000403459_enhanced           1

# %% [markdown]
# ## Fine-tuning the model

# %% [markdown]
# ### Preprocessing

# %%
from fmlct.function import preprocessing

# The path that stores your data including `Image` and `Mask`.
input_path = 'dataset/DATASET1'
input_csv = 'dataset/DATASET1/label.csv'
output = 'processed/DATASET1/preprocessed.csv'
preprocessing.preprocessing_main(input_path, input_csv, output)
# Out:
# => Image dir:  dataset/DATASET1/Image
# => Mask dir:  dataset/DATASET1/Mask
# => Output csv:  processed/DATASET1/preprocessed.csv
# => Label csv:  dataset/DATASET1/label.csv
# => Number of images:  35
# => Number of masks:  35
# => Number of images with mask:  35
# => Number of images with label:  35
#   0%|          | 0/35 [00:00<?, ?it/s]
# 100%|██████████| 35/35 [01:08<00:00,  1.97s/it]

# %% [markdown]
# ### Check the pre-precessing resutls

# %%
from fmlct.lib.utils import pytree

pytree.tree("processed/DATASET1", max_level=3, max_show=3)
# Out:
# DATASET1
# ├── all_roi_resize48
# │   ├── all_roi_resize48.csv
# │   ├── image
# │   │   ├── 1000287900_enhanced.nii.gz
# │   │   ├── 1000301641_enhanced.nii.gz
# │   │   ├── ...
# │   │   └── 1000340984_enhanced.nii.gz
# │   └── mask
# │       ├── 1000287900_enhanced.nii.gz
# │       ├── 1000301641_enhanced.nii.gz
# │       ├── ...
# │       └── 1000340984_enhanced.nii.gz
# └── preprocessed.csv

# %%
from fmlct.lib.utils import read_array, overlay_mask
from matplotlib import pyplot as plt
import numpy as np

# Selecting a slice from the dataset
demo_image = read_array("processed/DATASET1/all_roi_resize48/image/1000287900_enhanced.nii.gz")[23]
demo_mask = read_array("processed/DATASET1/all_roi_resize48/mask/1000287900_enhanced.nii.gz")[23]

# Plotting the images
fig, axes = plt.subplots(1, 3, figsize=(10, 5))

# Original image
axes[0].imshow(demo_image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Combined image and mask
axes[1].imshow(overlay_mask(demo_image, demo_mask, alpha=0.5))
axes[1].set_title('Image with Mask Overlay')
axes[1].axis('off')

# Mask
axes[2].imshow(demo_mask, cmap='gray')
axes[2].set_title('Mask')
axes[2].axis('off')

plt.show()

# %%
import pandas as pd

to_display_cols = ["Name", "coordX", "coordY",	"coordZ", "roi_start", "roi_end"]

# The ROI details of `processed/DATASET1/preprocessed.csv` is based on the original image.
print("The original image:")
display(pd.read_csv("processed/DATASET1/preprocessed.csv").head(1)[to_display_cols])

# The ROI details of `processed/DATASET1/all_roi_resize48/preprocessed.csv` is based on the resized image.
print("The resized image:")
display(pd.read_csv("processed/DATASET1/all_roi_resize48/all_roi_resize48.csv").head(1)[to_display_cols])
# Out:
# The original image:
#                        Name      coordX      coordY      coordZ  \
# 0  20211103_enhanced.nii.gz  307.268986  139.636723  214.671891
#
#          roi_start          roi_end
# 0  [295, 127, 201]  [320, 154, 228]
# The resized image:
#                        Name     coordX     coordY     coordZ  roi_start  \
# 0  20211103_enhanced.nii.gz  23.981851  22.792169  24.657206  [0, 0, 0]
#
#         roi_end
# 0  [48, 48, 48]

# %% [markdown]
# ### Fine-tuning Configs

# %% [markdown]
# ### Here is a demo provided by Monai
#
# tutorial: https://docs.monai.io/en/latest/config_syntax.html#monai-bundle-configuration

# %%
from monai.bundle import ConfigParser
import yaml
import json

demo_config = ConfigParser(yaml.load("""
                                     
# You can use Python code with `$`, but it will run instantly when parsing the config file.
whatever: "$print('Hello World!')" 
                                     
imports:
  - "$import datetime"

in_chans: 1
out_chans: 1
k_size: 3                                     
                                     
conv2d:
    _target_: torch.nn.Conv2d
    in_channels: "@in_chans"      # You can use `@` to refer to the variables defined above.
    out_channels: "@out_chans"
    kernel_size: "@k_size"
                                     
x:
    y: "from x"
    z:
        y: "from z"
        this: "@#y"               # @#A is to use A at the same config structure level
        above: "@##y"             # @##A refers to A at one level above.

now: "$datetime.datetime.now()" # You should import the module first
""", Loader=yaml.SafeLoader)).get_parsed_content()

print(demo_config["conv2d"]) # same as torch.nn.Conv2d(in_channels=1, out_channels=1, kernel_size=3)
print(demo_config["now"])
print(json.dumps(demo_config["x"], indent=4))
# Out:
# Hello World!
# Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1))
# 2024-02-22 13:29:17.325896
# {
#     "y": "from x",
#     "z": {
#         "y": "from z",
#         "this": "from z",
#         "above": "from x"
#     }
# }

# %% [markdown]
# ### Overview of the config file

# %%
config = ConfigParser()
config.read_config('experiments/finetune.yaml')

# %%
print(f"""
=> Output directory: "{config["output_root"] + "/" + config["run_name"]}"
=> Batch size: {config["batch_size"]}
=> Number of epochs: {config["epochs"]}
=> Pretrained model: "{config["pretrain"]}"

=> Training dataset: 
    _target_: {config["train_dataset_obj"]["_target_"]}
    csv_path: {config["train_dataset_obj"]["csv_path"]}
    label:    {config["train_dataset_obj"]["label"]}
    ...

=> Validation dataset:
    _target_: {config["val_dataset_obj"]["_target_"]}
    csv_path: {config["val_dataset_obj"]["csv_path"]}
    label:    {config["val_dataset_obj"]["label"]}
    ...
""")
# Out:
# => Output directory: "finetuning_out/DATASET1"
# => Batch size: 8
# => Number of epochs: 20
# => Pretrained model: "pretrained_checkpoint/lung_CT_checkpoint.pth.tar"
#
# => Training dataset:
#     _target_: fmlct.lib.datasets.PatchDataset
#     csv_path: processed/DATASET1/all_roi_resize48/all_roi_resize48.csv
#     label:    demo_label
#     ...
#
# => Validation dataset:
#     _target_: fmlct.lib.datasets.PatchDataset
#     csv_path: processed/DATASET1/all_roi_resize48/all_roi_resize48.csv
#     label:    demo_label
#     ...

# %% [markdown]
# ## Fine-tuning implementation

# %%
from fmlct.function.finetuning_main import finetuning_main

yaml_path = 'experiments/finetune.yaml'

finetuning_main(yaml_path)
# Out:
# single process
# Use GPU: 0 for training
# => creating model vit_3d_base_patchsize8 of arch None
# => Start loading pretrained weights from pretrained_checkpoint/lung_CT_checkpoint.pth.tar
# Loading messages:
#  _IncompatibleKeys(missing_keys=['pos_embed', 'head.weight', 'head.bias'], unexpected_keys=['fc_norm.weight', 'fc_norm.bias'])
# => Finish loading pretrained weights from pretrained_checkpoint/lung_CT_checkpoint.pth.tar
# => creating optimizer
# Param groups information is omitted...
# => changing learning rate to match batch size, lr *= batch_size / 256:  0.1
# => creating train dataloader
# => Train dataset length: 35
# => Val dataset length: 35
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.465 AP 0.624
# Epoch: [0][0/4]	Time  0.221 ( 0.221)	Data  0.193 ( 0.193)	Loss 5.2023e-01 (5.2023e-01)	AUC   0.29 (  0.29)	AP   0.52 (  0.52)
#  @ Train: Loss 0.83655 AUC 0.556 AP 0.636
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.496 AP 0.621
# Epoch: [1][0/4]	Time  0.053 ( 0.053)	Data  0.033 ( 0.033)	Loss 7.9025e-01 (7.9025e-01)	AUC   0.69 (  0.69)	AP   0.73 (  0.73)
#  @ Train: Loss 0.72757 AUC 0.620 AP 0.686
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.675 AP 0.741
# Epoch: [2][0/4]	Time  0.024 ( 0.024)	Data  0.008 ( 0.008)	Loss 7.5595e-01 (7.5595e-01)	AUC   0.40 (  0.40)	AP   0.54 (  0.54)
#  @ Train: Loss 0.86864 AUC 0.542 AP 0.645
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.630 AP 0.699
# Epoch: [3][0/4]	Time  0.023 ( 0.023)	Data  0.007 ( 0.007)	Loss 7.5546e-01 (7.5546e-01)	AUC   0.87 (  0.87)	AP   0.87 (  0.87)
#  @ Train: Loss 1.02403 AUC 0.696 AP 0.759
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.523 AP 0.682
# Epoch: [4][0/4]	Time  0.025 ( 0.025)	Data  0.009 ( 0.009)	Loss 7.4341e-01 (7.4341e-01)	AUC   0.86 (  0.86)	AP   0.74 (  0.74)
#  @ Train: Loss 0.99749 AUC 0.598 AP 0.671
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.569 AP 0.672
# Epoch: [5][0/4]	Time  0.027 ( 0.027)	Data  0.009 ( 0.009)	Loss 8.9937e-01 (8.9937e-01)	AUC   0.87 (  0.87)	AP   0.87 (  0.87)
#  @ Train: Loss 0.68258 AUC 0.796 AP 0.834
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.503 AP 0.679
# Epoch: [6][0/4]	Time  0.023 ( 0.023)	Data  0.008 ( 0.008)	Loss 9.8414e-01 (9.8414e-01)	AUC   0.62 (  0.62)	AP   0.73 (  0.73)
#  @ Train: Loss 1.17707 AUC 0.777 AP 0.788
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.636 AP 0.769
# Epoch: [7][0/4]	Time  0.023 ( 0.023)	Data  0.007 ( 0.007)	Loss 6.0040e-01 (6.0040e-01)	AUC   0.67 (  0.67)	AP   0.70 (  0.70)
#  @ Train: Loss 1.01016 AUC 0.717 AP 0.777
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.631 AP 0.738
# Epoch: [8][0/4]	Time  0.023 ( 0.023)	Data  0.007 ( 0.007)	Loss 5.6516e-01 (5.6516e-01)	AUC   0.88 (  0.88)	AP   0.90 (  0.90)
#  @ Train: Loss 0.78975 AUC 0.769 AP 0.825
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.665 AP 0.740
# Epoch: [9][0/4]	Time  0.025 ( 0.025)	Data  0.008 ( 0.008)	Loss 1.1880e+00 (1.1880e+00)	AUC   0.62 (  0.62)	AP   0.73 (  0.73)
#  @ Train: Loss 1.04347 AUC 0.823 AP 0.851
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.748 AP 0.815
# Epoch: [10][0/4]	Time  0.024 ( 0.024)	Data  0.008 ( 0.008)	Loss 1.4490e+00 (1.4490e+00)	AUC   1.00 (  1.00)	AP   1.00 (  1.00)
#  @ Train: Loss 1.47936 AUC 0.700 AP 0.786
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.710 AP 0.751
# Epoch: [11][0/4]	Time  0.025 ( 0.025)	Data  0.008 ( 0.008)	Loss 9.9245e-01 (9.9245e-01)	AUC   0.87 (  0.87)	AP   0.87 (  0.87)
#  @ Train: Loss 1.78343 AUC 0.734 AP 0.749
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.726 AP 0.803
# Epoch: [12][0/4]	Time  0.022 ( 0.022)	Data  0.007 ( 0.007)	Loss 5.3453e-01 (5.3453e-01)	AUC   1.00 (  1.00)	AP   1.00 (  1.00)
#  @ Train: Loss 1.08678 AUC 0.729 AP 0.753
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.702 AP 0.783
# Epoch: [13][0/4]	Time  0.023 ( 0.023)	Data  0.007 ( 0.007)	Loss 1.2458e+00 (1.2458e+00)	AUC   0.88 (  0.88)	AP   0.90 (  0.90)
#  @ Train: Loss 0.83866 AUC 0.762 AP 0.795
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.570 AP 0.735
# Epoch: [14][0/4]	Time  0.024 ( 0.024)	Data  0.008 ( 0.008)	Loss 8.3160e-01 (8.3160e-01)	AUC   0.67 (  0.67)	AP   0.77 (  0.77)
#  @ Train: Loss 0.84581 AUC 0.760 AP 0.812
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.676 AP 0.739
# Epoch: [15][0/4]	Time  0.023 ( 0.023)	Data  0.008 ( 0.008)	Loss 5.3561e-01 (5.3561e-01)	AUC   0.73 (  0.73)	AP   0.81 (  0.81)
#  @ Train: Loss 1.07854 AUC 0.819 AP 0.864
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.770 AP 0.795
# Epoch: [16][0/4]	Time  0.024 ( 0.024)	Data  0.008 ( 0.008)	Loss 4.3142e-01 (4.3142e-01)	AUC   0.86 (  0.86)	AP   0.74 (  0.74)
#  @ Train: Loss 1.29668 AUC 0.898 AP 0.882
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.777 AP 0.841
# Epoch: [17][0/4]	Time  0.022 ( 0.022)	Data  0.008 ( 0.008)	Loss 1.2598e+00 (1.2598e+00)	AUC   0.75 (  0.75)	AP   0.80 (  0.80)
#  @ Train: Loss 1.20858 AUC 0.804 AP 0.853
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.700 AP 0.768
# Epoch: [18][0/4]	Time  0.022 ( 0.022)	Data  0.007 ( 0.007)	Loss 1.0750e+00 (1.0750e+00)	AUC   0.98 (  0.98)	AP   0.99 (  0.99)
#  @ Train: Loss 2.10224 AUC 0.899 AP 0.918
# finetuning_out/DATASET1/ckpts
#  * Test: AUC 0.745 AP 0.853
# Epoch: [19][0/4]	Time  0.023 ( 0.023)	Data  0.007 ( 0.007)	Loss 7.1430e-01 (7.1430e-01)	AUC   0.93 (  0.93)	AP   0.94 (  0.94)
#  @ Train: Loss 1.13122 AUC 0.854 AP 0.869

# %% [markdown]
# ### Preview of the output

# %%
pytree.tree("finetuning_out/DATASET1", max_level=2)
# Out:
# DATASET1
# ├── cfgs
# │   ├── Feb22_12-52-16_lc_finetune.yaml
# │   └── Feb22_13-29-21_lc_finetune.yaml
# ├── ckpts
# │   ├── best.pth.tar
# │   ├── checkpoint_0004.pth.tar
# │   ├── ...
# │   └── checkpoint_0009.pth.tar
# └── logs
#     ├── Feb22_12-52-16_lc
#     └── Feb22_13-29-21_lc

# %% [markdown]
# #### Check the training and validation information. Note that, users should install tensorflow firstly.

# %%
from collections import defaultdict
from pathlib import Path
from tensorflow.python.summary.summary_iterator import summary_iterator

tb_log_path = sorted(Path("finetuning_out/DATASET1/logs").rglob("*tfevents*"))[-1]
metrics = defaultdict(list)
for event in summary_iterator(str(tb_log_path)):
    for value in event.summary.value:
        metrics[value.tag].append(value.simple_value)
# print(metrics.keys()) # ['val_loss', 'val_auc', 'val_ap', 'loss', 'auc', 'ap']

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 3, figsize=(16, 4), constrained_layout=True)

for i, metric in enumerate(['loss', 'auc', 'ap']):
    axes[0, i].plot(metrics[metric])
    axes[0, i].set_title(metric)
    axes[0, i].set_xlabel('Epoch')
    axes[0, i].set_ylabel(metric)

for i, metric in enumerate(['val_loss', 'val_auc', 'val_ap']):
    axes[1, i].plot(metrics[metric])
    axes[1, i].set_title(metric)
    axes[1, i].set_xlabel('Epoch')
    axes[1, i].set_ylabel(metric)

plt.show()
# Out:
# 2024-02-22 13:32:51.720502: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-22 13:32:51.720532: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-22 13:32:51.721336: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING:tensorflow:From /home/zhenwei/anaconda3/envs/fmlct/lib/python3.9/site-packages/tensorflow/python/summary/summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %% [markdown]
# ### Visualization by Grad-CAM

# %%
from fmlct.lib.utils import read_array, overlay_mask, set_seed
from fmlct.function.feature_extraction import load_model
from fmlct.third_libs.cam3d.api import run_vit_cam
import torch
import numpy as np
from matplotlib import pyplot as plt

# %%
demo_image = read_array("processed/DATASET1/all_roi_resize48/image/1000301641_enhanced.nii.gz")
demo_mask = read_array("processed/DATASET1/all_roi_resize48/mask/1000301641_enhanced.nii.gz")

input_tensor = torch.from_numpy(demo_image)[None, None] # Add batch and channel dimension
input_tensor = (input_tensor - input_tensor.mean()) / input_tensor.std() # Normalize

set_seed(6666)
model = load_model("finetuning_out/DATASET1/ckpts/best.pth.tar").to("cpu")

cam_img = run_vit_cam(model, input_tensor, 1) # 3d
# Out:
# => Start loading pretrained weights from finetuning_out/DATASET1/ckpts/best.pth.tar
# Loading messages:
#  _IncompatibleKeys(missing_keys=['head.weight', 'head.bias'], unexpected_keys=[])
# => Finish loading pretrained weights from finetuning_out/DATASET1/ckpts/best.pth.tar

# %%
slice_idx = 19
image_slice = demo_image[slice_idx]
mask_slice = demo_mask[slice_idx]
cam_slice = cam_img[slice_idx]


# Plotting the images
fig, axes = plt.subplots(1, 5, figsize=(10, 5))

# Original image
axes[0].imshow(image_slice, cmap='gray')
# axes[0].set_title('Original Image')
axes[0].axis('off')

# Mask
axes[1].imshow(mask_slice, cmap='gray')
# axes[1].set_title('Mask')
axes[1].axis('off')

# Gradcam
axes[2].imshow(cam_slice, cmap="jet")
# axes[2].set_title('Gradcam')
axes[2].axis('off')

# Combined image and gradcam
axes[3].imshow(image_slice, cmap="gray")
axes[3].imshow(cam_slice, cmap="jet", alpha=0.3)
# axes[3].set_title('Combined image and gradcam')
axes[3].axis('off')

# Displaying the contour plot
axes[4].imshow(image_slice, cmap='gray')
contours = axes[4].contour(cam_slice, levels=np.linspace(cam_slice.mean(), cam_slice.max(), num=10), cmap="jet", alpha=0.9)
# axes[4].clabel(contours, inline=True, fontsize=8)
# axes[4].set_title("Contour Plot")
axes[4].axis('off')

plt.show()
